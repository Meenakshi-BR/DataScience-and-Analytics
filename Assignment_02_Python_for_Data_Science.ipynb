# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1.Read the dataset to the python envirnment

# %%
df=pd.read_excel('/content/DOC-20240907-WA0005')
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2.Display the columns in the dataset

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3.Calculate the mean of each column of the dataset

# %%
column_mean=df.select_dtypes(include='number').mean()
column_mean
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4.Check for the null values present in the dataset.

# %%
df.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# 5.Perform meaningful visualizations using the dataset.Bring atleast 3 meaningful visualizations.

# %% [markdown]
# Boxplot

# %%
df1=df.set_index('Classification')
plt.boxplot(df1)
plt.show()

# %% [markdown]
# Scatter Plot

# %%
sns.scatterplot(x='SL',y='SW',data=df,hue='Classification',palette='deep')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %% [markdown]
# PairPlot

# %%
sns.pairplot(df,hue='Classification')
plt.suptitle('Pairplot of Iris dataset',y=1.02,fontsize=16)
plt.show()

# %% [markdown]
# HeatMap

# %%
sns.heatmap(df.select_dtypes(include='number').corr())
plt.title('Correlation Heatmap of Iris features')
plt.show()
